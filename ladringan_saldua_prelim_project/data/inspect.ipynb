# %%
import pandas as pd

# %%
# replace path to desired csv file
db = pd.read_csv("orders_export.csv")
# db = pd.read_csv("events.csv")

# %%
db.columns
# Out:
# Index(['order_id', 'session_id', 'product_department', 'item_price',
#        'cart_action_count', 'order_status', 'order_date'],
#       dtype='str')

# %%
db.head(10)
# Out:
#    order_id  session_id product_department  item_price  cart_action_count  \
# 0         1  LJuJVLEjPT        electronics       31.90                  0
# 1         2  4TMArHtXQy            UNKNOWN        9.81                  0
# 2         3  aGFYrNgC08          computers      113.81                  0
# 3         4  aa4mmk0kwQ            unknown       15.87                  0
# 4         5  vnkdP81DDW       CONSTRUCTION       52.33                  0
# 5         6  J1t6sIYXiV          Computers      215.41                  0
# 6         7  kVBeYDPcBw          computers       53.14                  0
# 7         8  F3VB9LYp39          computers       53.14                  0
# 8         9  63xjTFC54g          computers      268.17                  0
# 9        10  sF2S2yMO09        electronics      635.63                  0
#
#   order_status                 order_date
# 0    ABANDONED  2020-09-24 11:57:06+00:00
# 1    ABANDONED  2020-09-24 11:57:27+00:00
# ...

# %%
db.describe
# Out:
# <bound method NDFrame.describe of         order_id  session_id product_department  item_price  \
# 0              1  LJuJVLEjPT        electronics       31.90
# 1              2  4TMArHtXQy            UNKNOWN        9.81
# 2              3  aGFYrNgC08          computers      113.81
# 3              4  aa4mmk0kwQ            unknown       15.87
# 4              5  vnkdP81DDW       CONSTRUCTION       52.33
# ...          ...         ...                ...         ...
# 490393    490394  wZb7gP1zgN        Electronics       32.22
# 490394    490395  FRLqIttxKU            UNKNOwn      219.94
# 490395    490396  g6WqPf50Ma        electronics       80.03
# 490396    490397  xNIJBqZdkd        electronics       64.92
# 490397    490398  9pCbKMIcSx        electronics       10.16
#
#         cart_action_count order_status                 order_date
# 0                       0    ABANDONED  2020-09-24 11:57:06+00:00
# 1                       0    ABANDONED  2020-09-24 11:57:27+00:00
# ...

# %%
db.shape
# Out:
# (490398, 7)
